# %%
# %cd /content/drive/MyDrive/MLData
# Out:
# /content/drive/MyDrive/MLData

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import danych

# %%
data_df = pd.read_csv('heart_disease.csv')

# %% [markdown]
# Podgląd danych

# %%
data_df.head()
# Out:
#    Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 0    Male   39   postgraduate              0         0.0     0.0
# 1  Female   46  primaryschool              0         0.0     0.0
# 2    Male   48     uneducated              1        20.0     0.0
# 3  Female   61       graduate              1        30.0     0.0
# 4  Female   46       graduate              1        23.0     0.0
#
#   prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0              no             0         0    195.0  106.0   70.0  26.97
# 1              no             0         0    250.0  121.0   81.0  28.73
# 2              no             0         0    245.0  127.5   80.0  25.34
# 3              no             1         0    225.0  150.0   95.0  28.58
# 4              no             0         0    285.0  130.0   84.0  23.10
#
#    heartRate  glucose Heart_ stroke
# 0       80.0     77.0            No
# 1       95.0     76.0            No
# ...

# %%
data_df = data_df.rename(columns={'Heart_ stroke': 'heartStroke'})

# %% [markdown]
# Podgląd formatów

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           4238 non-null   object
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   object
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   object
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  heartStroke      4238 non-null   object
# ...

# %% [markdown]
# Poszukiwanie brakujacych wartości

# %%
data_df.isnull().sum().sort_values(ascending=False)
# Out:
# glucose            388
# education          105
# BPMeds              53
# totChol             50
# cigsPerDay          29
# BMI                 19
# heartRate            1
# Gender               0
# age                  0
# currentSmoker        0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# sysBP                0
# diaBP                0
# heartStroke          0
# dtype: int64

# %% [markdown]
# Wgląd w wartości BMI

# %%
#BMI

#Interpretacja wyniku
#<16,0	wygłodzenie
#16,0 – 16,9	wychudzenie
#17,0 - 18,5	niedowaga
#18,5–24,9	waga prawidłowa
#25,0–29,9	nadwaga
#30,0–34,9	otyłość I stopnia
#35,0–39,9	otyłość II stopnia
#≥40	otyłość III stopnia

# %% [markdown]
# Uzupełnianie brakujacych wartości

# %%
data_df['BMI'].fillna(data_df['BMI'].median(), inplace = True)

# %%
data_df['glucose'].fillna(data_df['glucose'].median(), inplace = True)

# %%
data_df['totChol'].fillna(data_df['totChol'].median(), inplace = True)

# %%
data_df['heartRate'].fillna(data_df['heartRate'].median(), inplace = True)

# %%
data_df['BPMeds'].mode()[0]   #sprawdzanie najczęstrzej wartości w celu uzupełnienia brakujących
# Out:
# 0.0

# %%
data_df['BPMeds'].fillna(data_df['BPMeds'].mode()[0], inplace = True) # uzupełnienie braków najczęstrzą wartością

# %%
#wypełnia brakujące wartości w kolumnie cigsPerDay na podstawie średniej dla palących i niepalących, a następnie uzupełnia brakujące wartości dla niepalących wartością 0
condition = data_df['currentSmoker'] == 0

data_df['cigsPerDay'] = data_df['cigsPerDay'].fillna(
    data_df.groupby('currentSmoker')['cigsPerDay'].transform('mean'))

data_df.loc[condition, 'cigsPerDay'] = 0

# %%
data_df['age'].min()
# Out:
# 32

# %%
data_df['age'].max()
# Out:
# 70

# %%
data_df['Age_bin']=pd.cut(data_df['age'], bins=[0,40,50,60,70],labels=['30-40', '41-50', '51-60', '61-70'])

# %%
data_df.tail(10)
# Out:
#       Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 4228  Female   50     uneducated              0         0.0     0.0
# 4229  Female   51       graduate              1        20.0     0.0
# 4230  Female   56     uneducated              1         3.0     0.0
# 4231    Male   58       graduate              0         0.0     0.0
# 4232    Male   68     uneducated              0         0.0     0.0
# 4233    Male   50     uneducated              1         1.0     0.0
# 4234    Male   51       graduate              1        43.0     0.0
# 4235  Female   48  primaryschool              1        20.0     0.0
# 4236  Female   44     uneducated              1        15.0     0.0
# 4237  Female   52  primaryschool              0         0.0     0.0
#
#      prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4228              no             1         1    260.0  190.0  130.0  43.67
# ...

# %%
data_df['BMI'].min()
# Out:
# 15.54

# %%
data_df['BMI'].max()
# Out:
# 56.8

# %%
data_df['BMI_bin'] = pd.cut(data_df['BMI'], bins=[0, 16, 16.9, 18.5, 24.9, 29.9, 34.9, 39.9, float('inf')], labels=['wygłodzenie', 'wychudzenie', 'niedowaga', 'waga prawidłowa', 'nadwaga', 'otyłość I stopnia', 'otyłość II stopnia', 'otyłość III stopnia'])

# %%
data_df['Chol_bin'] = pd.cut(data_df['totChol'], bins=[0, 200, 239, float('inf')], labels=['normalny', 'podwyższony', 'wysoki'])

    #Kategoria "normalny" odpowiada wartościom cholesterolu poniżej 200,
    #Kategoria "podwyższony" odpowiada wartościom cholesterolu od 200 do 239,
    #Kategoria "wysoki" odpowiada wartościom cholesterolu powyżej 240.

# %%
data_df['glucose_bin'] = pd.cut(data_df['glucose'], bins=[0, 99, 125, float('inf')], labels=['normalny', 'podwyższony', 'cukrzyca'])

    #Kategoria "normalny" odpowiada wartościom glukozy poniżej 100,
    #Kategoria "podwyższony" odpowiada wartościom glukozy od 100 do 125,
    #Kategoria "cukrzyca" odpowiada wartościom glukozy powyżej 126.

# %%
data_df['cigsPerDay'].max()
# Out:
# 70.0

# %%
data_df['cigsPerDay_bin'] = pd.cut(data_df['cigsPerDay'], bins=[-1, 0, 10, 20, 30, float('inf')], labels=['niepali', '1-10', '11-20', '21-30', 'więcej niż 30'])

# %%
# Sprawdzenie warunku logicznego, czy dla każdej osoby niepalącej jest 0 papierosów dziennie
is_zero_when_not_smoking = (data_df['currentSmoker'] == 0) & (data_df['cigsPerDay'] != 0.0)

# Wyświetlenie indeksów, gdzie warunek nie jest spełniony
print("Indeksy, gdzie w kolumnie currentSmoker jest 0, a w kolumnie cigsPerDay nie jest 0:")
print(data_df.index[is_zero_when_not_smoking].tolist())
# Out:
# Indeksy, gdzie w kolumnie currentSmoker jest 0, a w kolumnie cigsPerDay nie jest 0:
# []

# %%
data_df['HR_category'] = pd.cut(data_df['heartRate'], bins=[0, 60, 100, 150, float('inf')], labels=['niska', 'normalna', 'wysoka', 'bardzo wysoka'])

    #Niska (0-60 uderzeń na minutę): Częstość rytmu serca poniżej 60 uderzeń na minutę jest ogólnie uważana za niską i może wskazywać na bradykardię.
    #Normalna (60-100 uderzeń na minutę): To jest typowy zakres dla zdrowego dorosłego człowieka. Częstość rytmu serca w tym przedziale jest powszechnie akceptowana jako normalna.
    #Wysoka (100-150 uderzeń na minutę): Częstość rytmu serca powyżej 100 uderzeń na minutę może wskazywać na tachykardię. Zakres do 150 obejmuje zakres tachykardii, która jest częstością rytmu serca powyżej normy, ale niekiedy może być fizjologiczna, np. podczas wysiłku fizycznego.
    #Bardzo wysoka (powyżej 150 uderzeń na minutę): Częstość rytmu serca powyżej 150 uderzeń na minutę wskazuje na bardzo wysoką tachykardię, która zazwyczaj występuje w przypadku zaburzeń rytmu serca lub innych stanów patologicznych.

# %%
#BPMeds: Jest to zwykle zmienna binarna (0 lub 1), która wskazuje, czy dana osoba przyjmuje leki przeciwnadciśnieniowe (Blood Pressure Medications).
#Wartość 1 może oznaczać, że pacjent przyjmuje leki przeciwnadciśnieniowe, natomiast wartość 0 oznacza, że nie przyjmuje.
#Leki przeciwnadciśnieniowe są stosowane w leczeniu nadciśnienia tętniczego, pomagając obniżyć ciśnienie krwi do pożądanych poziomów.

#diaBP: Skrót ten odnosi się do diastolicznego ciśnienia krwi (Diastolic Blood Pressure).
#Jest to jedna z dwóch podstawowych wartości, które są mierzone podczas pomiaru ciśnienia krwi.
#Diastoliczne ciśnienie krwi odnosi się do wartości ciśnienia krwi w naczyniach krwionośnych w czasie relaksacji lub rozkurczu serca, gdy komory serca się wypełniają krwią.
#Jest to druga liczba w standardowym odczycie ciśnienia krwi, np. 120/80 mm Hg, gdzie 80 oznacza diastoliczne ciśnienie krwi.

# %%
# Zakresy dla podziału danych
bins_sys = [0, 90, 120, 140, 160, float('inf')]  # Przykładowe wartości graniczne dla sysBP
bins_dia = [0, 60, 80, 90, 100, float('inf')]     # Przykładowe wartości graniczne dla diaBP

# Etykiety dla przedziałów
labels = ['niskie', 'prawidłowe', 'wysokie', 'bardzo wysokie', 'nadciśnienie skrajne']

# Funkcja klasyfikująca ciśnienie krwi na podstawie sysBP i diaBP
def classify_blood_pressure(sysBP, diaBP):
    if sysBP <= 90 and diaBP <= 60:
        return 'niskie'
    elif sysBP <= 120 and diaBP <= 80:
        return 'prawidłowe'
    elif sysBP <= 140 and diaBP <= 90:
        return 'wysokie'
    elif sysBP <= 160 and diaBP <= 100:
        return 'bardzo wysokie'
    else:
        return 'nadciśnienie skrajne'

# Tworzenie nowej kolumny 'blood_pressure_category' na podstawie klasyfikacji sysBP i diaBP
data_df['blood_pressure_category'] = data_df.apply(lambda row: classify_blood_pressure(row['sysBP'], row['diaBP']), axis=1)

# %%
data_df.tail()
# Out:
#       Gender  age      education  currentSmoker  cigsPerDay  BPMeds  \
# 4233    Male   50     uneducated              1         1.0     0.0
# 4234    Male   51       graduate              1        43.0     0.0
# 4235  Female   48  primaryschool              1        20.0     0.0
# 4236  Female   44     uneducated              1        15.0     0.0
# 4237  Female   52  primaryschool              0         0.0     0.0
#
#      prevalentStroke  prevalentHyp  diabetes  totChol  ...  heartRate  \
# 4233              no             1         0    313.0  ...       66.0
# 4234              no             0         0    207.0  ...       65.0
# 4235              no             0         0    248.0  ...       84.0
# 4236              no             0         0    210.0  ...       86.0
# 4237              no             0         0    269.0  ...       80.0
#
#       glucose  heartStroke  Age_bin          BMI_bin     Chol_bin  \
# ...

# %%
data_df['BPMeds'].value_counts()
# Out:
# 0.0    4114
# 1.0     124
# Name: BPMeds, dtype: int64

# %%
data_df['prevalentHyp'] = data_df['prevalentHyp'].replace({0: 'Nie', 1: 'Tak'})

# %%
data_df['BPMeds'] = data_df['BPMeds'].replace({0.0: 'Nie', 1.0: 'Tak'})

# %%
data_df['diabetes'] = data_df['diabetes'].replace({0: 'Nie', 1: 'Tak'})

# %%
data_df['prevalentStroke'] = data_df['prevalentStroke'].replace({'no': 'Nie', 'yes': 'Tak'})

# %%
data_df['heartStroke'] = data_df['heartStroke'].replace({'No': 'Nie', 'yes': 'Tak'})

# %%
data_df['Gender'] = data_df['Gender'].replace({'Male': 'Mężczyzna', 'Female': 'Kobieta'})

# %%
drop_column = ['BMI','cigsPerDay', 'age','heartRate','currentSmoker','glucose', 'totChol','sysBP','diaBP','education']
data_df.drop(drop_column, axis = 1, inplace = True)

# %%
data_df.tail()
# Out:
#          Gender BPMeds prevalentStroke prevalentHyp diabetes heartStroke  \
# 4233  Mężczyzna    Nie             Nie          Tak      Nie         Tak
# 4234  Mężczyzna    Nie             Nie          Nie      Nie         Nie
# 4235    Kobieta    Nie             Nie          Nie      Nie         Nie
# 4236    Kobieta    Nie             Nie          Nie      Nie         Nie
# 4237    Kobieta    Nie             Nie          Nie      Nie         Nie
#
#      Age_bin          BMI_bin     Chol_bin  glucose_bin cigsPerDay_bin  \
# 4233   41-50          nadwaga       wysoki     normalny           1-10
# 4234   51-60  waga prawidłowa  podwyższony     normalny  więcej niż 30
# 4235   41-50  waga prawidłowa       wysoki     normalny          11-20
# 4236   41-50  waga prawidłowa  podwyższony     normalny          11-20
# 4237   51-60  waga prawidłowa       wysoki  podwyższony        niepali
#
#      HR_category blood_pressure_category
# 4233    normalna    nadciśnienie skrajne
# ...
